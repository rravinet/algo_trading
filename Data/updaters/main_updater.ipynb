# %%
from connect import engine, Daily_Stock_Data, Hourly_Stock_Data, Minute_Stock_Data, Stock_Splits, Stock_News, Company_Financials
from log_config import setup_logging
from get_company_data import Company_Financials_updater
from get_daily_data_sql import Market_Data_updater
from get_fin_news import News_Update
from get_stock_splits import Stock_Splits_update
import pandas as pd
import logging
from datetime import datetime, timedelta
import datetime as dt
import pytz
from polygon import RESTClient
from dotenv import load_dotenv
import os

# %%
setup_logging()

# %%
load_dotenv()
key = os.getenv("API_KEY")

# %%
client = RESTClient(api_key=key)

# %%
wiki = 'http://en.wikipedia.org/wiki'
djia_ticker_list = wiki + '/Dow_Jones_Industrial_Average'
sp500_tickers_list = wiki + '/List_of_S%26P_500_companies'
tickersSP500 = pd.read_html(sp500_tickers_list)[0].Symbol.to_list()
djia_tickers = pd.read_html(djia_ticker_list)[1].Symbol.to_list()

# %%
#Need to use multiprocessing or asyncio however don't really have the time to implement now

company_financials_updater = Company_Financials_updater(tickers=djia_tickers, engine=engine)
market_data_updater = Market_Data_updater(tickers=djia_tickers, engine=engine)
news_update = News_Update(tickers=djia_tickers, engine=engine)
stock_splits_update = Stock_Splits_update(tickers=djia_tickers, engine=engine)


company_financials_updater.update_data(client)
market_data_updater.update_data(client)
news_update.update_data(client)
stock_splits_update.update_data(client)
# Out:
# 2024-04-15 09:25:49,693 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-15 09:25:49,697 INFO sqlalchemy.engine.Engine INSERT INTO company_financials (company_name, start_date, end_date, filing_date, fiscal_period, financials, fiscal_year) VALUES (%(company_name__0)s, %(start_date__0)s, %(end_date__0)s, %(filing_date__0)s, %(fiscal_period__0)s, %(financials__0)s, %(f ... 153006 characters truncated ... ate__999)s, %(filing_date__999)s, %(fiscal_period__999)s, %(financials__999)s, %(fiscal_year__999)s)
# 2024-04-15 09:25:49,698 INFO sqlalchemy.engine.Engine [generated in 0.02788s (insertmanyvalues) 1/3 (unordered)] {'financials__0': '"{\\"balance_sheet\\": {\\"long_term_debt\\": {\\"formula\\": null, \\"label\\": \\"Long-term Debt\\", \\"order\\": 810, \\"unit\\": \\"USD\\", \\"va ... (5403 characters truncated) ... ues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 32681000000.0, \\"xpath\\": null}}}"', 'start_date__0': Timestamp('2023-01-01 00:00:00'), 'company_name__0': '3M CO', 'end_date__0': Timestamp('2023-12-31 00:00:00'), 'filing_date__0': Timestamp('2024-02-07 00:00:00'), 'fiscal_period__0': 'TTM', 'fiscal_year__0': '2023', 'financials__1': '"{\\"balance_sheet\\": {\\"liabilities_and_equity\\": {\\"formula\\": null, \\"label\\": \\"Liabilities And Equity\\", \\"order\\": 1900, \\"unit\\": ... (5403 characters truncated) ... nues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 8013000000.0, \\"xpath\\": null}}}"', 'start_date__1': Timestamp('2023-10-01 00:00:00'), 'company_name__1': '3M CO', 'end_date__1': Timestamp('2023-12-31 00:00:00'), 'filing_date__1': NaT, 'fiscal_period__1': 'Q4', 'fiscal_year__1': '2023', 'financials__2': '"{\\"balance_sheet\\": {\\"prepaid_expenses\\": {\\"formula\\": null, \\"label\\": \\"Prepaid Expenses\\", \\"order\\": 240, \\"unit\\": \\"USD\\", \ ... (5403 characters truncated) ... ues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 32681000000.0, \\"xpath\\": null}}}"', 'start_date__2': Timestamp('2023-01-01 00:00:00'), 'company_name__2': '3M CO', 'end_date__2': Timestamp('2023-12-31 00:00:00'), 'filing_date__2': Timestamp('2024-02-07 00:00:00'), 'fiscal_period__2': 'FY', 'fiscal_year__2': '2023', 'financials__3': '"{\\"balance_sheet\\": {\\"current_liabilities\\": {\\"formula\\": null, \\"label\\": \\"Current Liabilities\\", \\"order\\": 700, \\"unit\\": \\"USD ... (5396 characters truncated) ... nues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 8312000000.0, \\"xpath\\": null}}}"', 'start_date__3': Timestamp('2023-07-01 00:00:00'), 'company_name__3': '3M CO', 'end_date__3': Timestamp('2023-09-30 00:00:00'), 'filing_date__3': Timestamp('2023-10-24 00:00:00'), 'fiscal_period__3': 'Q3', 'fiscal_year__3': '2023', 'financials__4': '"{\\"balance_sheet\\": {\\"other_current_assets\\": {\\"formula\\": null, \\"label\\": \\"Other Current Assets\\", \\"order\\": 250, \\"unit\\": \\"U ... (5382 characters truncated) ... nues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 8325000000.0, \\"xpath\\": null}}}"', 'start_date__4': Timestamp('2023-04-01 00:00:00'), 'company_name__4': '3M CO', 'end_date__4': Timestamp('2023-06-30 00:00:00'), 'filing_date__4': Timestamp('2023-07-25 00:00:00'), 'fiscal_period__4': 'Q2', 'fiscal_year__4': '2023', 'financials__5': '"{\\"balance_sheet\\": {\\"prepaid_expenses\\": {\\"formula\\": null, \\"label\\": \\"Prepaid Expenses\\", \\"order\\": 240, \\"unit\\": \\"USD\\", \ ... (5379 characters truncated) ... nues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 8031000000.0, \\"xpath\\": null}}}"', 'start_date__5': Timestamp('2023-01-01 00:00:00'), 'company_name__5': '3M CO', 'end_date__5': Timestamp('2023-03-31 00:00:00'), 'filing_date__5': Timestamp('2023-04-25 00:00:00'), 'fiscal_period__5': 'Q1', 'fiscal_year__5': '2023', 'financials__6': '"{\\"balance_sheet\\": {\\"other_noncurrent_assets\\": {\\"formula\\": null, \\"label\\": \\"Other Non-current Assets\\", \\"order\\": 350, \\"unit\\ ... (5406 characters truncated) ... nues\\": {\\"formula\\": null, \\"label\\": \\"Revenues\\", \\"order\\": 100, \\"unit\\": \\"USD\\", \\"value\\": 8079000000.0, \\"xpath\\": null}}}"', 'start_date__6': Timestamp('20 ...
# 2024-04-15 09:25:50,299 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-04-15 09:25:50,303 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-15 09:25:50,303 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,304 INFO sqlalchemy.engine.Engine [generated in 0.00066s] {'ticker_1': 'MMM'}
# 2024-04-15 09:25:50,445 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,446 INFO sqlalchemy.engine.Engine [cached since 0.1425s ago] {'ticker_1': 'AXP'}
# 2024-04-15 09:25:50,454 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,454 INFO sqlalchemy.engine.Engine [cached since 0.1511s ago] {'ticker_1': 'AMGN'}
# 2024-04-15 09:25:50,462 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,463 INFO sqlalchemy.engine.Engine [cached since 0.1595s ago] {'ticker_1': 'AMZN'}
# 2024-04-15 09:25:50,471 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,471 INFO sqlalchemy.engine.Engine [cached since 0.168s ago] {'ticker_1': 'AAPL'}
# 2024-04-15 09:25:50,480 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,480 INFO sqlalchemy.engine.Engine [cached since 0.1771s ago] {'ticker_1': 'BA'}
# 2024-04-15 09:25:50,491 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,491 INFO sqlalchemy.engine.Engine [cached since 0.188s ago] {'ticker_1': 'CAT'}
# 2024-04-15 09:25:50,500 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,501 INFO sqlalchemy.engine.Engine [cached since 0.1977s ago] {'ticker_1': 'CVX'}
# 2024-04-15 09:25:50,509 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,509 INFO sqlalchemy.engine.Engine [cached since 0.2063s ago] {'ticker_1': 'CSCO'}
# 2024-04-15 09:25:50,517 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,517 INFO sqlalchemy.engine.Engine [cached since 0.2143s ago] {'ticker_1': 'KO'}
# 2024-04-15 09:25:50,525 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,525 INFO sqlalchemy.engine.Engine [cached since 0.2223s ago] {'ticker_1': 'DIS'}
# 2024-04-15 09:25:50,533 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,534 INFO sqlalchemy.engine.Engine [cached since 0.2304s ago] {'ticker_1': 'DOW'}
# 2024-04-15 09:25:50,541 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,542 INFO sqlalchemy.engine.Engine [cached since 0.2386s ago] {'ticker_1': 'GS'}
# 2024-04-15 09:25:50,550 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,550 INFO sqlalchemy.engine.Engine [cached since 0.2468s ago] {'ticker_1': 'HD'}
# 2024-04-15 09:25:50,558 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,558 INFO sqlalchemy.engine.Engine [cached since 0.255s ago] {'ticker_1': 'HON'}
# 2024-04-15 09:25:50,566 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,566 INFO sqlalchemy.engine.Engine [cached since 0.2632s ago] {'ticker_1': 'IBM'}
# 2024-04-15 09:25:50,574 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,575 INFO sqlalchemy.engine.Engine [cached since 0.2716s ago] {'ticker_1': 'INTC'}
# 2024-04-15 09:25:50,582 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,583 INFO sqlalchemy.engine.Engine [cached since 0.2795s ago] {'ticker_1': 'JNJ'}
# 2024-04-15 09:25:50,591 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,591 INFO sqlalchemy.engine.Engine [cached since 0.2877s ago] {'ticker_1': 'JPM'}
# 2024-04-15 09:25:50,599 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,599 INFO sqlalchemy.engine.Engine [cached since 0.2958s ago] {'ticker_1': 'MCD'}
# 2024-04-15 09:25:50,607 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,607 INFO sqlalchemy.engine.Engine [cached since 0.3041s ago] {'ticker_1': 'MRK'}
# 2024-04-15 09:25:50,615 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,615 INFO sqlalchemy.engine.Engine [cached since 0.3124s ago] {'ticker_1': 'MSFT'}
# 2024-04-15 09:25:50,623 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,624 INFO sqlalchemy.engine.Engine [cached since 0.3205s ago] {'ticker_1': 'NKE'}
# 2024-04-15 09:25:50,631 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,632 INFO sqlalchemy.engine.Engine [cached since 0.3286s ago] {'ticker_1': 'PG'}
# 2024-04-15 09:25:50,639 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,640 INFO sqlalchemy.engine.Engine [cached since 0.3366s ago] {'ticker_1': 'CRM'}
# 2024-04-15 09:25:50,650 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,651 INFO sqlalchemy.engine.Engine [cached since 0.3477s ago] {'ticker_1': 'TRV'}
# 2024-04-15 09:25:50,664 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,666 INFO sqlalchemy.engine.Engine [cached since 0.3629s ago] {'ticker_1': 'UNH'}
# 2024-04-15 09:25:50,677 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,678 INFO sqlalchemy.engine.Engine [cached since 0.3747s ago] {'ticker_1': 'VZ'}
# 2024-04-15 09:25:50,689 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,690 INFO sqlalchemy.engine.Engine [cached since 0.3872s ago] {'ticker_1': 'V'}
# 2024-04-15 09:25:50,700 INFO sqlalchemy.engine.Engine SELECT max(daily_stock_data.date) AS max_1
# FROM daily_stock_data
# WHERE daily_stock_data.ticker = %(ticker_1)s
# 2024-04-15 09:25:50,702 INFO sqlalchemy.engine.Engine [cached since 0.3986s ago] {'ticker_1': 'WMT'}
# 2024-04-15 09:25:50,711 INFO sqlalchemy.engine.Engine ROLLBACK
# 2024-04-15 09:25:50,712 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-15 09:25:50,713 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:50,714 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {'ticker_queried_1': 'MMM'}
# 2024-04-15 09:25:52,808 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:52,809 INFO sqlalchemy.engine.Engine [cached since 2.096s ago] {'ticker_queried_1': 'AXP'}
# 2024-04-15 09:25:53,387 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:53,388 INFO sqlalchemy.engine.Engine [cached since 2.675s ago] {'ticker_queried_1': 'AMGN'}
# 2024-04-15 09:25:53,960 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:53,961 INFO sqlalchemy.engine.Engine [cached since 3.248s ago] {'ticker_queried_1': 'AMZN'}
# 2024-04-15 09:25:54,539 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:54,540 INFO sqlalchemy.engine.Engine [cached since 3.827s ago] {'ticker_queried_1': 'AAPL'}
# 2024-04-15 09:25:55,130 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:55,131 INFO sqlalchemy.engine.Engine [cached since 4.418s ago] {'ticker_queried_1': 'BA'}
# 2024-04-15 09:25:55,775 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:55,775 INFO sqlalchemy.engine.Engine [cached since 5.063s ago] {'ticker_queried_1': 'CAT'}
# 2024-04-15 09:25:56,391 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:56,392 INFO sqlalchemy.engine.Engine [cached since 5.679s ago] {'ticker_queried_1': 'CVX'}
# 2024-04-15 09:25:56,969 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:56,971 INFO sqlalchemy.engine.Engine [cached since 6.258s ago] {'ticker_queried_1': 'CSCO'}
# 2024-04-15 09:25:57,563 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:57,564 INFO sqlalchemy.engine.Engine [cached since 6.851s ago] {'ticker_queried_1': 'KO'}
# 2024-04-15 09:25:58,234 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:58,235 INFO sqlalchemy.engine.Engine [cached since 7.523s ago] {'ticker_queried_1': 'DIS'}
# 2024-04-15 09:25:58,842 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:58,843 INFO sqlalchemy.engine.Engine [cached since 8.13s ago] {'ticker_queried_1': 'DOW'}
# 2024-04-15 09:25:59,420 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:25:59,421 INFO sqlalchemy.engine.Engine [cached since 8.708s ago] {'ticker_queried_1': 'GS'}
# 2024-04-15 09:26:00,078 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:00,080 INFO sqlalchemy.engine.Engine [cached since 9.367s ago] {'ticker_queried_1': 'HD'}
# 2024-04-15 09:26:00,651 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:00,652 INFO sqlalchemy.engine.Engine [cached since 9.939s ago] {'ticker_queried_1': 'HON'}
# 2024-04-15 09:26:01,350 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:01,352 INFO sqlalchemy.engine.Engine [cached since 10.64s ago] {'ticker_queried_1': 'IBM'}
# 2024-04-15 09:26:01,929 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:01,930 INFO sqlalchemy.engine.Engine [cached since 11.22s ago] {'ticker_queried_1': 'INTC'}
# 2024-04-15 09:26:02,511 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:02,512 INFO sqlalchemy.engine.Engine [cached since 11.8s ago] {'ticker_queried_1': 'JNJ'}
# 2024-04-15 09:26:03,093 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:03,095 INFO sqlalchemy.engine.Engine [cached since 12.38s ago] {'ticker_queried_1': 'JPM'}
# 2024-04-15 09:26:03,763 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:03,765 INFO sqlalchemy.engine.Engine [cached since 13.05s ago] {'ticker_queried_1': 'MCD'}
# 2024-04-15 09:26:04,347 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:04,349 INFO sqlalchemy.engine.Engine [cached since 13.64s ago] {'ticker_queried_1': 'MRK'}
# 2024-04-15 09:26:04,992 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:04,993 INFO sqlalchemy.engine.Engine [cached since 14.28s ago] {'ticker_queried_1': 'MSFT'}
# 2024-04-15 09:26:05,694 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:05,695 INFO sqlalchemy.engine.Engine [cached since 14.98s ago] {'ticker_queried_1': 'NKE'}
# 2024-04-15 09:26:06,266 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:06,267 INFO sqlalchemy.engine.Engine [cached since 15.55s ago] {'ticker_queried_1': 'PG'}
# 2024-04-15 09:26:06,935 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:06,936 INFO sqlalchemy.engine.Engine [cached since 16.22s ago] {'ticker_queried_1': 'CRM'}
# 2024-04-15 09:26:07,954 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:07,956 INFO sqlalchemy.engine.Engine [cached since 17.24s ago] {'ticker_queried_1': 'TRV'}
# 2024-04-15 09:26:08,541 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:08,542 INFO sqlalchemy.engine.Engine [cached since 17.83s ago] {'ticker_queried_1': 'UNH'}
# 2024-04-15 09:26:09,292 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:09,293 INFO sqlalchemy.engine.Engine [cached since 18.58s ago] {'ticker_queried_1': 'VZ'}
# 2024-04-15 09:26:09,872 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:09,873 INFO sqlalchemy.engine.Engine [cached since 19.16s ago] {'ticker_queried_1': 'V'}
# 2024-04-15 09:26:10,521 INFO sqlalchemy.engine.Engine SELECT max(stock_news.published_utc) AS max_1
# FROM stock_news
# WHERE stock_news.ticker_queried = %(ticker_queried_1)s
# 2024-04-15 09:26:10,523 INFO sqlalchemy.engine.Engine [cached since 19.81s ago] {'ticker_queried_1': 'WMT'}
# 2024-04-15 09:26:11,096 INFO sqlalchemy.engine.Engine COMMIT
